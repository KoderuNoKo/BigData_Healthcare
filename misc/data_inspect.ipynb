# %%
import pandas as pd

# read the first n rows
df_sample = pd.read_csv("../data/mimic-iv-ed-2.2/ed/triage.csv", nrows=1000)

# %%
print(df_sample.head())
print(df_sample.dtypes)
# Out:
#    subject_id   stay_id  temperature  heartrate  resprate  o2sat    sbp   dbp  \
# 0    10000032  32952584         97.8       87.0      14.0   97.0   71.0  43.0
# 1    10000032  33258284         98.4       70.0      16.0   97.0  106.0  63.0
# 2    10000032  35968195         99.4      105.0      18.0   96.0  106.0  57.0
# 3    10000032  38112554         98.9       88.0      18.0   97.0  116.0  88.0
# 4    10000032  39399961         98.7       77.0      16.0   98.0   96.0  50.0
#
#   pain  acuity                            chiefcomplaint
# 0    7     2.0                               Hypotension
# 1    0     3.0            Abd pain, Abdominal distention
# 2   10     3.0                           n/v/d, Abd pain
# 3   10     3.0                      Abdominal distention
# 4   13     2.0  Abdominal distention, Abd pain, LETHAGIC
# subject_id          int64
# stay_id             int64
# temperature       float64
# heartrate         float64
# resprate          float64
# ...

# %%
df_sample = pd.read_csv("../data/mimic-iv-3.1/icu/chartevents.csv", nrows=1000)
print(df_sample.head())
print(df_sample.dtypes)
# Out:
#    subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0    10000032  29079034  39553978       18704.0  2180-07-23 12:36:00
# 1    10000032  29079034  39553978       18704.0  2180-07-23 12:36:00
# 2    10000032  29079034  39553978       18704.0  2180-07-23 12:36:00
# 3    10000032  29079034  39553978       18704.0  2180-07-23 14:00:00
# 4    10000032  29079034  39553978       18704.0  2180-07-23 14:00:00
#
#              storetime  itemid              value  valuenum valueuom  warning
# 0  2180-07-23 14:45:00  226512               39.4      39.4       kg        0
# 1  2180-07-23 14:45:00  226707                 60      60.0     Inch        0
# 2  2180-07-23 14:45:00  226730                152     152.0       cm        0
# 3  2180-07-23 14:18:00  220048  SR (Sinus Rhythm)       NaN      NaN        0
# 4  2180-07-23 14:18:00  224642               Oral       NaN      NaN        0
# subject_id        int64
# hadm_id           int64
# stay_id           int64
# ...
